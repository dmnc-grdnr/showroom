# %%
import network_visualization

# %%
g = network_visualization.random_network(10,22) # erstellt einen zufälligen Graphen mit 10 Knoten und 22 Kanten

# %%
print(g)
# Out:
# IGRAPH UN-- 10 22 --
# + attr: name (v), count (e)
# + edges (vertex names):
#      Extern -- 192.168.0.1, 192.168.0.2, 192.168.0.3, 192.168.0.5, 192.168.0.8
# 192.168.0.1 -- Extern, 192.168.0.7, 192.168.0.9
# 192.168.0.2 -- Extern, 192.168.0.3, 192.168.0.7, 192.168.0.8
# 192.168.0.3 -- Extern, 192.168.0.2, 192.168.0.4, 192.168.0.5, 192.168.0.6,
# 192.168.0.8, 192.168.0.9
# 192.168.0.4 -- 192.168.0.3, 192.168.0.6, 192.168.0.7
# 192.168.0.5 -- Extern, 192.168.0.3, 192.168.0.7, 192.168.0.8
# 192.168.0.6 -- 192.168.0.3, 192.168.0.4, 192.168.0.7, 192.168.0.8, 192.168.0.9
# 192.168.0.7 -- 192.168.0.1, 192.168.0.2, 192.168.0.4, 192.168.0.5, 192.168.0.6
# 192.168.0.8 -- Extern, 192.168.0.2, 192.168.0.3, 192.168.0.5, 192.168.0.6
# 192.168.0.9 -- 192.168.0.1, 192.168.0.3, 192.168.0.6

# %%
network_visualization.plot_network(g)
